# %% [markdown]
# <a href="https://colab.research.google.com/github/bhagyashreeekanamadi/BOGO/blob/main/IMdb_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/content/tmdb_movies_data.csv')

# %%
df.head()
# Out:
#        id    imdb_id  popularity     budget     revenue  \
# 0  135397  tt0369610   32.985763  150000000  1513528810
# 1   76341  tt1392190   28.419936  150000000   378436354
# 2  262500  tt2908446   13.112507  110000000   295238201
# 3  140607  tt2488496   11.173104  200000000  2068178225
# 4  168259  tt2820852    9.335014  190000000  1506249360
#
#                  original_title  \
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...
#
#                                             homepage          director  \
# ...

# %%
df.tail()
# Out:
#           id    imdb_id  popularity  budget  revenue  \
# 10861     21  tt0060371    0.080598       0        0
# 10862  20379  tt0060472    0.065543       0        0
# 10863  39768  tt0060161    0.065141       0        0
# 10864  21449  tt0061177    0.064317       0        0
# 10865  22293  tt0060666    0.035919   19000        0
#
#                  original_title  \
# 10861        The Endless Summer
# 10862                Grand Prix
# 10863       Beregis Avtomobilya
# 10864    What's Up, Tiger Lily?
# 10865  Manos: The Hands of Fate
#
#                                                     cast homepage  \
# 10861  Michael Hynson|Robert August|Lord 'Tally Ho' B...      NaN
# 10862  James Garner|Eva Marie Saint|Yves Montand|Tosh...      NaN
# 10863  Innokentiy Smoktunovskiy|Oleg Efremov|Georgi Z...      NaN
# 10864  Tatsuya Mihashi|Akiko Wakabayashi|Mie Hama|Joh...      NaN
# 10865  Harold P. Warren|Tom Neyman|John Reynolds|Dian...      NaN
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10866 entries, 0 to 10865
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    10866 non-null  int64
#  1   imdb_id               10856 non-null  object
#  2   popularity            10866 non-null  float64
#  3   budget                10866 non-null  int64
#  4   revenue               10866 non-null  int64
#  5   original_title        10866 non-null  object
#  6   cast                  10790 non-null  object
#  7   homepage              2936 non-null   object
#  8   director              10822 non-null  object
#  9   tagline               8042 non-null   object
#  10  keywords              9373 non-null   object
#  11  overview              10862 non-null  object
#  12  runtime               10866 non-null  int64
#  13  genres                10843 non-null  object
#  14  production_companies  9836 non-null   object
# ...

# %%
df.describe()
# Out:
#                   id    popularity        budget       revenue       runtime  \
# count   10866.000000  10866.000000  1.086600e+04  1.086600e+04  10866.000000
# mean    66064.177434      0.646441  1.462570e+07  3.982332e+07    102.070863
# std     92130.136561      1.000185  3.091321e+07  1.170035e+08     31.381405
# min         5.000000      0.000065  0.000000e+00  0.000000e+00      0.000000
# 25%     10596.250000      0.207583  0.000000e+00  0.000000e+00     90.000000
# 50%     20669.000000      0.383856  0.000000e+00  0.000000e+00     99.000000
# 75%     75610.000000      0.713817  1.500000e+07  2.400000e+07    111.000000
# max    417859.000000     32.985763  4.250000e+08  2.781506e+09    900.000000
#
#          vote_count  vote_average  release_year    budget_adj   revenue_adj
# count  10866.000000  10866.000000  10866.000000  1.086600e+04  1.086600e+04
# mean     217.389748      5.974922   2001.322658  1.755104e+07  5.136436e+07
# ...

# %%
df.isnull().sum()
# Out:
# id                         0
# imdb_id                   10
# popularity                 0
# budget                     0
# revenue                    0
# original_title             0
# cast                      76
# homepage                7930
# director                  44
# tagline                 2824
# keywords                1493
# overview                   4
# runtime                    0
# genres                    23
# production_companies    1030
# release_date               0
# vote_count                 0
# vote_average               0
# release_year               0
# budget_adj                 0
# revenue_adj                0
# dtype: int64

# %%
df.columns
# Out:
# Index(['id', 'imdb_id', 'popularity', 'budget', 'revenue', 'original_title',
#        'cast', 'homepage', 'director', 'tagline', 'keywords', 'overview',
#        'runtime', 'genres', 'production_companies', 'release_date',
#        'vote_count', 'vote_average', 'release_year', 'budget_adj',
#        'revenue_adj'],
#       dtype='object')

# %%
df.shape
# Out:
# (10866, 21)

# %%
#Which year has the highest release of movies?
df['release_year'].value_counts().sort_values(ascending=False).head(1)
# Out:
# release_year
# 2014    700
# Name: count, dtype: int64

# %%
df.groupby('release_year')['id'].count().sort_values(ascending=False).head(1)
# Out:
# release_year
# 2014    700
# Name: id, dtype: int64

# %%
#Top 10 movies which earn highest profit
df['profit']=df['revenue']-df['budget']
df.groupby('original_title')['profit'].sum().sort_values(ascending=False).head(10)
# Out:
# original_title
# Avatar                                          2544505847
# Star Wars: The Force Awakens                    1868178225
# Titanic                                         1632034188
# Jurassic World                                  1363528810
# Furious 7                                       1316249360
# The Avengers                                    1288080742
# Harry Potter and the Deathly Hallows: Part 2    1202817822
# Frozen                                          1127284869
# Avengers: Age of Ultron                         1125035767
# The Net                                         1084279658
# Name: profit, dtype: int64

# %%
df.sort_values(by='profit',ascending=False)[['original_title','profit']].head(10)
# Out:
#                                     original_title      profit
# 1386                                        Avatar  2544505847
# 3                     Star Wars: The Force Awakens  1868178225
# 5231                                       Titanic  1645034188
# 0                                   Jurassic World  1363528810
# 4                                        Furious 7  1316249360
# 4361                                  The Avengers  1299557910
# 3374  Harry Potter and the Deathly Hallows: Part 2  1202817822
# 14                         Avengers: Age of Ultron  1125035767
# 5422                                        Frozen  1124219009
# 8094                                       The Net  1084279658

# %%
#Movie with Highest And Lowest Budget?

# %%
df[df['budget'].max()==df['budget']]['original_title']
# Out:
# 2244    The Warrior's Way
# Name: original_title, dtype: object

# %%
df[df['budget']==1]['original_title']
# Out:
# 1151                           Fear Clinic
# 2618                          Lost & Found
# 3065    Angus, Thongs and Perfect Snogging
# 3581               Love, Wedding, Marriage
# Name: original_title, dtype: object

# %%
#Which movie made the highest revenue and lowest as well?
df.columns
# Out:
# Index(['id', 'imdb_id', 'popularity', 'budget', 'revenue', 'original_title',
#        'cast', 'homepage', 'director', 'tagline', 'keywords', 'overview',
#        'runtime', 'genres', 'production_companies', 'release_date',
#        'vote_count', 'vote_average', 'release_year', 'budget_adj',
#        'revenue_adj', 'profit'],
#       dtype='object')

# %%
df[df['revenue'].max()==df['revenue']]['original_title']
# Out:
# 1386    Avatar
# Name: original_title, dtype: object

# %%
df[df['revenue'].min()==df['revenue']]['original_title']
# Out:
# 48                            Wild Card
# 67                             Survivor
# 74               Mythica: The Darkspore
# 75       Me and Earl and the Dying Girl
# 92             Mythica: The Necromancer
#                       ...
# 10861                The Endless Summer
# 10862                        Grand Prix
# 10863               Beregis Avtomobilya
# 10864            What's Up, Tiger Lily?
# 10865          Manos: The Hands of Fate
# Name: original_title, Length: 6016, dtype: object

# %%
#Movie with shorest and longest runtime?
df.columns
# Out:
# Index(['id', 'imdb_id', 'popularity', 'budget', 'revenue', 'original_title',
#        'cast', 'homepage', 'director', 'tagline', 'keywords', 'overview',
#        'runtime', 'genres', 'production_companies', 'release_date',
#        'vote_count', 'vote_average', 'release_year', 'budget_adj',
#        'revenue_adj', 'profit'],
#       dtype='object')

# %%
df[df['runtime'].max()==df['runtime']][['original_title','runtime']]
# Out:
#                      original_title  runtime
# 3894  The Story of Film: An Odyssey      900

# %%
df[df['runtime'].min()==df['runtime']][['original_title','runtime']]
# Out:
#                      original_title  runtime
# 92         Mythica: The Necromancer        0
# 334                         Ronaldo        0
# 410                  Anarchy Parlor        0
# 445   The Exorcism of Molly Hartley        0
# 486              If There Be Thorns        0
# 595                       Deep Dark        0
# 616                    The Outfield        0
# 1241                      Dance-Off        0
# 1289                      Treehouse        0
# 1293                       Tim Maia        0
# 1849                   Spectacular!        0
# 2315           Listen to Your Heart        0
# 2370                Freshman Father        0
# 3329       Grande, grosso e Verdone        0
# 3794           Toi, moi, les autres        0
# 3857                       Cell 213        0
# 3884                         eCupid        0
# 4063         Madea's Family Reunion        0
# 4138             A Time for Dancing        0
# 4829                           Rags        0
# ...

# %%
#Which movie get the highest or lowest votes (Ratings).
df.columns
# Out:
# Index(['id', 'imdb_id', 'popularity', 'budget', 'revenue', 'original_title',
#        'cast', 'homepage', 'director', 'tagline', 'keywords', 'overview',
#        'runtime', 'genres', 'production_companies', 'release_date',
#        'vote_count', 'vote_average', 'release_year', 'budget_adj',
#        'revenue_adj', 'profit'],
#       dtype='object')

# %%
df[df['vote_average'].max()==df['vote_average']][['original_title','vote_average']]
# Out:
#                      original_title  vote_average
# 3894  The Story of Film: An Odyssey           9.2

# %%
df[df['vote_average'].min()==df['vote_average']][['original_title','vote_average']]
# Out:
#                  original_title  vote_average
# 7772              Transmorphers           1.5
# 10865  Manos: The Hands of Fate           1.5

# %%
#Which Year Has The Highest Profit Rate?

df.columns
# Out:
# Index(['id', 'imdb_id', 'popularity', 'budget', 'revenue', 'original_title',
#        'cast', 'homepage', 'director', 'tagline', 'keywords', 'overview',
#        'runtime', 'genres', 'production_companies', 'release_date',
#        'vote_count', 'vote_average', 'release_year', 'budget_adj',
#        'revenue_adj', 'profit'],
#       dtype='object')

# %%
df.groupby('release_year')['profit'].mean().sort_values(ascending=False).head(1)
# Out:
# release_year
# 1995    3.594547e+07
# Name: profit, dtype: float64

# %%
#Which length movies most liked by the audiences according to their popularity?
df.groupby('runtime')['popularity'].mean().sort_values(ascending=False).head(3)
# Out:
# runtime
# 169    7.279679
# 194    4.355219
# 201    3.687482
# Name: popularity, dtype: float64

# %%
#Average Runtime Of Movies From Year To Year?
df.groupby('release_year')['runtime'].mean()
# Out:
# release_year
# 1960    110.656250
# 1961    119.419355
# 1962    124.343750
# 1963    111.323529
# 1964    109.214286
# 1965    118.171429
# 1966    106.891304
# 1967    104.950000
# 1968    107.282051
# 1969    106.580645
# 1970    112.048780
# 1971    107.727273
# 1972    101.950000
# 1973    103.527273
# 1974    105.617021
# 1975    107.363636
# 1976    109.319149
# 1977    107.105263
# 1978    110.076923
# 1979    112.017544
# 1980    107.500000
# 1981    105.865854
# 1982    103.925926
# 1983    103.000000
# 1984    103.466667
# 1985    114.339450
# 1986     99.933884
# 1987    101.168000
# 1988    101.793103
# 1989    104.781022
# 1990    105.651515
# 1991    105.112782
# 1992    107.030075
# 1993    107.123596
# 1994    106.913043
# 1995    107.548571
# 1996    105.705882
# 1997    106.505208
# 1998    105.061905
# 1999    108.861607
# 2000    103.779736
# 2001    108.033058
# 2002    106.864662
# 2003    100.679715
# 2004    105.364821
# 2005    102.686813
# ...
